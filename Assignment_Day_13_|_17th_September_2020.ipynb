# %% [markdown]
# Question:
# Prepare a case study for the given Dataset implement the following steps:
# Steps:
# 1. Import different required library
# 2. Check the version of Library
# 3. Go for different observation like Info, description
# 4. Check null Values
# 5. Check duplicate values
# 6. Filter for different condition - come up with insights from the dataset , basic plot , distribution plots
# 7. Use a histogram to plot different columns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6c861b75-839b-4451-9f44-d34d57be1b5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c861b75-839b-4451-9f44-d34d57be1b5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving creditcard.csv to creditcard (1).csv

# %%
import pandas as pd
df = pd.read_csv("creditcard.csv")
df
# Out:
#         Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0          0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    '0'
# 1          0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    '0'
# 2          1 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    '0'
# 3          1 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    '0'
# 4          2 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    '0'
# ...      ...       ...       ...       ...  ...       ...       ...     ...    ...
# 26340  34015 -0.370614 -2.895272  0.285578  ... -0.146962  0.127260  756.43    '0'
# 26341  34016  1.231792 -0.449297  0.966716  ...  0.095225  0.027797    9.38    '0'
# 26342  34016  1.290259 -0.749291  0.991513  ...  0.050730  0.012137   11.00    '0'
# 26343  34017 -1.356534 -0.741640  1.639658  ... -0.099813  0.359417   84.65    '0'
# 26344  34018  1.155958 -0.763421       NaN  ...       NaN       NaN     NaN    NaN
#
# [26345 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26345 entries, 0 to 26344
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    26345 non-null  int64
#  1   V1      26345 non-null  float64
#  2   V2      26345 non-null  float64
#  3   V3      26344 non-null  float64
#  4   V4      26344 non-null  float64
#  5   V5      26344 non-null  float64
#  6   V6      26344 non-null  float64
#  7   V7      26344 non-null  float64
#  8   V8      26344 non-null  float64
#  9   V9      26344 non-null  float64
#  10  V10     26344 non-null  float64
#  11  V11     26344 non-null  float64
#  12  V12     26344 non-null  float64
#  13  V13     26344 non-null  float64
#  14  V14     26344 non-null  float64
#  15  V15     26344 non-null  float64
#  16  V16     26344 non-null  float64
#  17  V17     26344 non-null  float64
#  18  V18     26344 non-null  float64
#  19  V19     26344 non-null  float64
#  20  V20     26344 non-null  float64
#  21  V21     26344 non-null  float64
#  22  V22     26344 non-null  float64
#  23  V23     26344 non-null  float64
#  24  V24     26344 non-null  float64
#  25  V25     26344 non-null  float64
#  26  V26     26344 non-null  float64
#  27  V27     26344 non-null  float64
#  28  V28     26344 non-null  float64
#  29  Amount  26344 non-null  float64
#  30  Class   26344 non-null  object
# dtypes: float64(29), int64(1), object(1)
# memory usage: 6.2+ MB

# %%
df.describe()
# Out:
#                Time            V1  ...           V28        Amount
# count  26345.000000  26345.000000  ...  26344.000000  26344.000000
# mean   19655.685633     -0.224128  ...      0.004221     76.047901
# std    11712.500045      1.884570  ...      0.279620    218.900452
# min        0.000000    -30.552380  ...     -9.617915      0.000000
# 25%     8024.000000     -0.951916  ...     -0.008663      6.150000
# 50%    23140.000000     -0.266367  ...      0.020044     19.020000
# 75%    30533.000000      1.166616  ...      0.076877     68.012500
# max    34018.000000      1.960497  ...      4.860769   7879.420000
#
# [8 rows x 30 columns]

# %%
df.isnull()
# Out:
#         Time     V1     V2     V3     V4  ...    V26    V27    V28  Amount  Class
# 0      False  False  False  False  False  ...  False  False  False   False  False
# 1      False  False  False  False  False  ...  False  False  False   False  False
# 2      False  False  False  False  False  ...  False  False  False   False  False
# 3      False  False  False  False  False  ...  False  False  False   False  False
# 4      False  False  False  False  False  ...  False  False  False   False  False
# ...      ...    ...    ...    ...    ...  ...    ...    ...    ...     ...    ...
# 26340  False  False  False  False  False  ...  False  False  False   False  False
# 26341  False  False  False  False  False  ...  False  False  False   False  False
# 26342  False  False  False  False  False  ...  False  False  False   False  False
# 26343  False  False  False  False  False  ...  False  False  False   False  False
# 26344  False  False  False   True   True  ...   True   True   True    True   True
#
# [26345 rows x 31 columns]

# %%
df['Time'].duplicated()
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 26340    False
# 26341    False
# 26342     True
# 26343    False
# 26344    False
# Name: Time, Length: 26345, dtype: bool

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26340    False
# 26341    False
# 26342    False
# 26343    False
# 26344    False
# Length: 26345, dtype: bool

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.plot(x="Time", y="Amount")
plt.show()

# %%
df.plot(x="Time", y=["V1", "V2", "V28"], kind="bar")

# %%
sns.distplot(df['Time'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
